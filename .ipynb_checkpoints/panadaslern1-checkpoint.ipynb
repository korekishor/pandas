# %%
import pandas as pd
read_data=pd.read_csv('pokemon_data.csv')
print(read_data)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# in other directory read file
import pandas as pd
read_data=pd.read_csv(r'C:\Users\Kishor Kore\Desktop\deep\file_name.csv')
print(read_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Kishor Kore\Desktop\pandas\.ipynb_checkpoints\panadaslern1-checkpoint.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000002?line=0'>1</a> # in other directory read file
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000002?line=1'>2</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000002?line=2'>3</a> read_data=pd.read_csv(r'C:\Users\Kishor Kore\Desktop\deep\file_name.csv')
# ...

# %%
import pandas as pd
ReadExcel=pd.read_excel('pokemon_data.xlsx')
print(ReadExcel)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Kishor Kore\Desktop\pandas\.ipynb_checkpoints\panadaslern1-checkpoint.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000003?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000003?line=1'>2</a> ReadExcel=pd.read_excel('pokemon_data.xlsx')
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000003?line=2'>3</a> print(ReadExcel)
#
# ...

# %%
read_text=pd.read_csv('pokemon_data.txt')
read_text=pd.read_csv('pokemon_data.txt',delimiter='\t')
print(read_text)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# first_nthdata
ReadExcel.head(4)
ReadExcel.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
colum_name=ReadExcel.columns
print(colum_name)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
import pandas as pd
ReadExcel=pd.read_excel('pokemon_data.xlsx')
# print(ReadExcel)
# print("--------------------------------------")
# print(ReadExcel['name'])
print(ReadExcel.iloc[0:4])
print(ReadExcel.iloc[23:25])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
#      #                 Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 23  18  PidgeotMega Pidgeot  Normal  Flying  83      80       80      135
# 24  19              Rattata  Normal     NaN  30      56       35       25
#
#     Sp. Def  Speed  Generation  Legendary
# 23       80    121           1      False
# 24       35     72           1      False

# %%
import pandas as pd
ReadExcel=pd.read_excel('pokemon_data.xlsx')
for index,row in ReadExcel.iterrows():
    print(index,row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Kishor Kore\Desktop\pandas\.ipynb_checkpoints\panadaslern1-checkpoint.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000008?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000008?line=1'>2</a> ReadExcel=pd.read_excel('pokemon_data.xlsx')
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000008?line=2'>3</a> for index,row in ReadExcel.iterrows():
# ...

# %%
import pandas as pd
ReadExcel=pd.read_excel('pokemon_data.xlsx')
# for index,row in ReadExcel.iterrows():
#      print(index,row['Name'])
# labels of pandas DataFrame(loc)
ReadExcel.loc[ReadExcel['Type 1']=="Grass" ]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
ReadExcel.sort_values('Name',ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
ReadExcel.columns
ReadExcel['Total']=ReadExcel['HP']+ReadExcel['Attack']+ReadExcel['Defense']+ReadExcel['Speed']
print(ReadExcel)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    188
# ...

# %%
# ReadExcel.drop(columns=["Total"])
# ReadExcel['total']=ReadExcel.iloc[4:6].sum(axis=1)
# ReadExcel.drop(columns=["total"])
print(ReadExcel)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total   total
# ...

# %%
print(ReadExcel)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total   total
# ...

# %%
import pandas as pd
ReadExcel=pd.read_excel('pokemon_data.xlsx')
ReadExcel['total']=ReadExcel.iloc[:,4:7].sum(axis=1)
print(ReadExcel)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  total
# 0         65       65     45           1      False    143
# ...

# %%
import pandas as pd
ReadExcel=pd.read_excel('pokemon_data.xlsx')
columns=ReadExcel.columns
print(columns)
columsn_value=list(ReadExcel.columns.values)
print(columsn_value)
print(ReadExcel[['Name','HP']])
new_csv=ReadExcel[['Name','HP']]
ReadExcel.to_csv('new_csv.csv',index=False)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']
#                       Name  HP
# 0                Bulbasaur  45
# 1                  Ivysaur  60
# 2                 Venusaur  80
# 3    VenusaurMega Venusaur  80
# 4               Charmander  39
# ..                     ...  ..
# 795                Diancie  50
# 796    DiancieMega Diancie  50
# 797    HoopaHoopa Confined  80
# 798     HoopaHoopa Unbound  80
# 799              Volcanion  80
#
# [800 rows x 2 columns]

# %%
ReadExcel.to_excel('new_excel.xlsx',index=False)

# %%
ReadExcel.loc[(ReadExcel['Type 1']=='Grass') & (ReadExcel['Name']=='Ivysaur')]
# ReadExcel.loc[(ReadExcel['Type 1']=='Grass') & (ReadExcel['Type 2']=='poison')]
# Out:
#    #     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2  Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 1           1      False

# %%
ReadExcel.loc[(ReadExcel['Type 1']=='Grass') | (ReadExcel['Type 2']=='poison') |(ReadExcel['HP']>300) ]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# ReadExcel['Type 1']=="Grass"
ReadExcel.loc[ReadExcel['Name'].str.contains("Mega")]
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   80     100      123
# 7      6  CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     9    BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19    15      BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23    18        PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87    80        SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102   94          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137  127          PinsirMega Pinsir       Bug    Flying   65     155      120
# ...

# %%
# delete data in name contain an mega

ReadExcel.loc[~ReadExcel['Name'].str.contains("Mega")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Kishor Kore\Desktop\pandas\.ipynb_checkpoints\panadaslern1-checkpoint.ipynb Cell 21 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000020?line=0'>1</a> # delete data in name contain an mega
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Kishor%20Kore/Desktop/pandas/.ipynb_checkpoints/panadaslern1-checkpoint.ipynb#ch0000020?line=2'>3</a> ReadExcel.loc[~ReadExcel['Name'].str.contains("Mega")]
#
# NameError: name 'ReadExcel' is not defined

# %%
import re
match=re.findall("[0-9]")
ReadExcel.loc[ReadExcel['Name'].str.contains("Mega",regex=true)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [116], in <cell line: 2>()
#       1 import re
# ----> 2 match=re.findall[0-9]
#       3 ReadExcel.loc[ReadExcel['Name'].str.contains("Mega",regex=true)]
#
# TypeError: 'function' object is not subscriptable
